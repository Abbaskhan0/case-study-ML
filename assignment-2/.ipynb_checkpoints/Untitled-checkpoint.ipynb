# %% [markdown]
# # Image Classification using CNN on MNIST data

# %% [markdown]
# ## Installing & Loading Libraries

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import numpy as np
import os
import random
# Out:
# 2025-05-04 14:40:02.204015: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-04 14:40:02.237431: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746349802.275657   34671 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746349802.287237   34671 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1746349802.314595   34671 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746349802.314641   34671 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746349802.314644   34671 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746349802.314647   34671 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-05-04 14:40:02.324058: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Creating config for variables

# %%
CONFIG = {
    "batch_size": 128,
    "epochs": 5, 
    "lr": 0.0005, 
    "seed": 42,
#     "save_model": True,
    "model_path": "Model/mnist_cnn_tf.keras",
    "log_device_placement": False 
}
os.environ['PYTHONHASHSEED'] = str(CONFIG["seed"])
random.seed(CONFIG["seed"])
np.random.seed(CONFIG["seed"])
tf.random.set_seed(CONFIG["seed"])
tf.config.set_soft_device_placement(True) 
tf.debugging.set_log_device_placement(CONFIG["log_device_placement"])

# %% [markdown]
# ## Data Loading - Util funciton

# %%
def load_and_preprocess_data():
   
    (x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

#  Nromalising and preprocessing
    x_train = x_train.astype("float32") / 255.0
    x_test = x_test.astype("float32") / 255.0

   
    x_train = np.expand_dims(x_train, -1)
    x_test = np.expand_dims(x_test, -1)

    print("Dataset loaded and preprocessed successfully.")
    print(f"  x_train shape: {x_train.shape}")
    print(f"  y_train shape: {y_train.shape}")
    print(f"  x_test shape: {x_test.shape}")  
    print(f"  y_test shape: {y_test.shape}")  
    return x_train, y_train, x_test, y_test

# %%
x_train, y_train, x_test, y_test = load_and_preprocess_data()
# Out:
# Loading MNIST dataset...
# Dataset loaded and preprocessed successfully.
#   x_train shape: (60000, 28, 28, 1)
#   y_train shape: (60000,)
#   x_test shape: (10000, 28, 28, 1)
#   y_test shape: (10000,)

# %%
# x_train[0][0] ,

# %% [markdown]
# ## Model LOading - Util funcitons

# %% [markdown]
# Builds a simple Sequential CNN model using Keras.
#
# Architecture: Conv2D -> ReLU -> MaxPool2D -> Conv2D -> ReLU -> MaxPool2D -> Flatten -> Dropout -> Dense -> ReLU -> Dense -> Softmax

# %%
def build_simple_cnn(input_shape, num_classes):
    
    model = keras.Sequential(
        [
            keras.Input(shape=input_shape),
            # First convolutional block
            layers.Conv2D(32, kernel_size=(3, 3), activation="relu", padding="same"),
            layers.MaxPooling2D(pool_size=(2, 2)),
            # Second convolutional block
            layers.Conv2D(64, kernel_size=(3, 3), activation="relu", padding="same"),
            layers.MaxPooling2D(pool_size=(2, 2)),
            # Flatten and Dense layers
            layers.Flatten(),
            layers.Dropout(0.35), # Dropout layer corresponding to PyTorch version
            layers.Dense(128, activation="relu"),
            # Output layer - Use softmax for multi-class probabilities
            layers.Dense(num_classes, activation="softmax"),
        ]
    )
    return model

# %%
m = build_simple_cnn((28, 28, 1) ,10 )
m.summary()
del m
# Out:
# 2025-05-04 14:40:08.741432: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 28, 28, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 14, 14, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 3136)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 3136)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       401,536 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 421,642 (1.61 MB)
#  Trainable params: 421,642 (1.61 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Model Inferencing & plotting learning curves : Util functions

# %%
def infer_tf(model, x_test, y_test):
 
    print("\n--- Inference on Sample Images (TensorFlow) ---")

 
    sample_indices = {}
    for i in range(len(y_test)):
        label = y_test[i]
        if label not in sample_indices:
            sample_indices[label] = i
        if len(sample_indices) == 10: 
            break

    # Sort indices by label for ordered output
    sorted_indices = sorted(sample_indices.items())

    fig, axes = plt.subplots(2, 5, figsize=(12, 6))
    fig.suptitle("Inference Results on Sample MNIST Digits (TensorFlow)")
    axes = axes.ravel()

    for i, (label, index) in enumerate(sorted_indices):
        image = x_test[index]
        true_label = y_test[index]

      
        image_batch = np.expand_dims(image, axis=0)

        # Perform inference
        predictions = model.predict(image_batch, verbose=0) 
        pred_prob = predictions[0] 
        pred_label = np.argmax(pred_prob)

        print(f"Sample Digit: {true_label}")
        print(f"  Predicted Label: {pred_label}")
        # print(f"  Predicted Probabilities: {pred_prob}")

       
        img_display = image.squeeze() # Remove channel and batch dims
        axes[i].imshow(img_display, cmap='gray')
        axes[i].set_title(f"True: {true_label}\nPred: {pred_label}")
        axes[i].axis('off')

    plt.tight_layout(rect=[0, 0.03, 1, 0.95])

    plot_path = "mnist_inference_results_tf.png"
    plt.savefig(plot_path)
    print(f"\nInference plot saved to {plot_path}")
    # plt.show() 

# --- Plotting Function ---
def plot_history(history, config):

    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs_range = range(1, config["epochs"] + 1)

    # Plot Loss
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, loss, marker='o', label='Training Loss')
    plt.plot(epochs_range, val_loss, marker='o', label='Validation (Test) Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss (Sparse Categorical Crossentropy)')
    plt.grid(True)
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, acc, marker='o', label='Training Accuracy')
    plt.plot(epochs_range, val_acc, marker='o', label='Validation (Test) Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.ylim(bottom=max(0, min(val_acc)*100 - 5)/100, top=1.01) 
    plt.grid(True)

    plt.tight_layout()
    # Save the plot
    plot_path = "mnist_history_tf.png"
    plt.savefig(plot_path)
    print(f"Training history plot saved to {plot_path}")
    # plt.show()

# %% [markdown]
# ## Training

# %%
input_shape = x_train.shape[1:]
num_classes = 10
model = build_simple_cnn(input_shape, num_classes)
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)               │ (None, 28, 28, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 14, 14, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 3136)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 3136)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │       401,536 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 421,642 (1.61 MB)
#  Trainable params: 421,642 (1.61 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
optimizer = keras.optimizers.Adam(learning_rate=CONFIG["lr"])
model.compile(
        loss="sparse_categorical_crossentropy",
        optimizer=optimizer,
        metrics=["accuracy"]
    )

# %%
history = model.fit(
        x_train,
        y_train,
        batch_size=CONFIG["batch_size"],
        epochs=CONFIG["epochs"],
        validation_data=(x_test, y_test), 
        verbose=1
    )
# Out:
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 28s 55ms/step - accuracy: 0.8279 - loss: 0.6085 - val_accuracy: 0.9764 - val_loss: 0.0755
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 27s 57ms/step - accuracy: 0.9730 - loss: 0.0914 - val_accuracy: 0.9842 - val_loss: 0.0482
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 28s 59ms/step - accuracy: 0.9811 - loss: 0.0637 - val_accuracy: 0.9869 - val_loss: 0.0392
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 27s 58ms/step - accuracy: 0.9843 - loss: 0.0502 - val_accuracy: 0.9885 - val_loss: 0.0344
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 26s 55ms/step - accuracy: 0.9873 - loss: 0.0411 - val_accuracy: 0.9898 - val_loss: 0.0294

# %% [markdown]
# ## Plotting Training curves

# %%
plot_history(history, CONFIG)
# Out:
# Training history plot saved to mnist_history_tf.png

# %% [markdown]
# ## Inferencing Sample

# %%
infer_tf(model, x_test, y_test)
# Out:
# --- Inference on Sample Images (TensorFlow) ---
# Sample Digit: 0
#   Predicted Label: 0
# Sample Digit: 1
#   Predicted Label: 1
# Sample Digit: 2
#   Predicted Label: 2
# Sample Digit: 3
#   Predicted Label: 3
# Sample Digit: 4
#   Predicted Label: 4
# Sample Digit: 5
#   Predicted Label: 5
# Sample Digit: 6
#   Predicted Label: 6
# Sample Digit: 7
#   Predicted Label: 7
# Sample Digit: 8
#   Predicted Label: 8
# Sample Digit: 9
#   Predicted Label: 9
#
# Inference plot saved to mnist_inference_results_tf.png

# %% [markdown]
# ## Saving Model

# %%
model.save("Model/cnn.keras")

# %% [markdown]
# ## Loading Model and running inferencing

# %%
model = keras.models.load_model("Model/cnn.keras")

# %%
from inference import predict_digit

# %%
directory = 'test/'
allfiles = []
for filename in os.listdir(directory):
    if os.path.isfile(os.path.join(directory, filename)):
        allfiles.append("test/"+filename)

# %%
for i in allfiles:
    predict_digit(i , model)
# Out:
# Detected light background, inverting image colors for model.
# Image preprocessed successfully. Shape for model: (1, 28, 28, 1)
# Performing prediction...
#
# Prediction complete:
#   Predicted Digit: 2
#   Confidence: 21.82%
# Error processing image: cannot identify image file 'test/number-small-2.png'
# Detected light background, inverting image colors for model.
# Image preprocessed successfully. Shape for model: (1, 28, 28, 1)
# Performing prediction...
#
# Prediction complete:
#   Predicted Digit: 3
#   Confidence: 55.21%
# Detected light background, inverting image colors for model.
# Image preprocessed successfully. Shape for model: (1, 28, 28, 1)
# Performing prediction...
#
# Prediction complete:
#   Predicted Digit: 1
#   Confidence: 99.68%
# Detected light background, inverting image colors for model.
# Image preprocessed successfully. Shape for model: (1, 28, 28, 1)
# Performing prediction...
#
# Prediction complete:
#   Predicted Digit: 8
#   Confidence: 21.77%
# Detected light background, inverting image colors for model.
# Image preprocessed successfully. Shape for model: (1, 28, 28, 1)
# Performing prediction...
#
# Prediction complete:
#   Predicted Digit: 9
#   Confidence: 30.47%
# Detected light background, inverting image colors for model.
# Image preprocessed successfully. Shape for model: (1, 28, 28, 1)
# Performing prediction...
#
# Prediction complete:
#   Predicted Digit: 9
#   Confidence: 87.77%
# Detected light background, inverting image colors for model.
# Image preprocessed successfully. Shape for model: (1, 28, 28, 1)
# Performing prediction...
#
# Prediction complete:
#   Predicted Digit: 1
#   Confidence: 53.11%
# Detected light background, inverting image colors for model.
# Image preprocessed successfully. Shape for model: (1, 28, 28, 1)
# Performing prediction...
#
# Prediction complete:
#   Predicted Digit: 8
#   Confidence: 17.86%
# Detected light background, inverting image colors for model.
# Image preprocessed successfully. Shape for model: (1, 28, 28, 1)
# Performing prediction...
#
# Prediction complete:
#   Predicted Digit: 5
#   Confidence: 85.26%
# Detected light background, inverting image colors for model.
# Image preprocessed successfully. Shape for model: (1, 28, 28, 1)
# Performing prediction...
#
# Prediction complete:
#   Predicted Digit: 8
#   Confidence: 37.12%
# Detected light background, inverting image colors for model.
# Image preprocessed successfully. Shape for model: (1, 28, 28, 1)
# Performing prediction...
#
# Prediction complete:
#   Predicted Digit: 7
#   Confidence: 95.69%
# Detected light background, inverting image colors for model.
# Image preprocessed successfully. Shape for model: (1, 28, 28, 1)
# Performing prediction...
#
# Prediction complete:
#   Predicted Digit: 8
#   Confidence: 22.89%
